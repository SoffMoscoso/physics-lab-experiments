# %%
import serial
import numpy as np
import pandas as pd

ser = serial.Serial("/dev/ttyUSB0", 115200, timeout=1)
ser.write(b"a")  # envía 'a' para iniciar la transmisión de datos
data = []

for i in range(300):  # número de muestras
    line = ser.readline().decode().strip()
    print(line) # para monitorear
    values = list(map(float, line.split(',')))
    data.append(values)

print(data)

labels = [0]*300 + [1]*300 + [2]*300

train_data = np.array(data)
train_labels = np.array(labels)

# normalizar
train_data = train_data / 10.0
# guardar en CSV
df = pd.DataFrame(train_data, columns=['x', 'y', 'z'])
df['label'] = train_labels
df.to_csv("train_data_static.csv", index=False)
# Out:
# 0.04,0.18,-7.97
# 0.28,0.31,-7.86
# 0.05,0.20,-8.05
# 0.09,0.38,-8.06
# 0.25,0.07,-8.33
# 0.46,0.12,-8.08
# 0.51,-0.17,-8.12
# 0.37,0.26,-8.16
# 0.13,0.66,-8.00
# 0.51,0.24,-7.87
# 0.11,0.42,-8.03
# -0.14,0.48,-8.19
# 0.13,0.15,-7.86
# -0.15,0.01,-7.82
# 0.00,0.00,-8.08
# 0.18,0.63,-8.04
# 0.23,-0.10,-7.98
# 0.40,0.18,-8.15
# -0.14,0.48,-8.04
# -0.04,-0.08,-8.12
# 0.49,0.51,-8.03
# 0.53,0.24,-7.85
# 0.17,0.03,-8.23
# -0.09,0.08,-8.14
# 0.11,0.28,-7.97
# 0.41,0.57,-8.20
# 0.26,0.31,-8.28
# 0.35,0.16,-8.03
# 0.65,0.81,-7.93
# 0.16,0.06,-8.09
# -0.07,0.77,-8.11
# 0.25,0.89,-7.72
# 0.47,0.50,-7.79
# -0.02,0.57,-7.75
# 0.26,0.49,-8.16
# 0.43,0.40,-7.83
# 0.17,0.32,-8.09
# 0.33,0.00,-7.90
# 0.10,0.05,-7.81
# -0.00,0.83,-8.09
# 0.41,0.57,-8.26
# 0.63,0.33,-7.92
# 0.11,0.22,-7.90
# 0.13,0.17,-8.21
# 0.36,0.18,-7.95
# 0.35,0.16,-8.15
# 0.39,0.47,-7.76
# 0.17,0.11,-7.92
# 0.48,0.22,-7.88
# -0.14,0.51,-7.72
# 0.01,0.25,-8.03
# 0.03,0.85,-7.93
# 0.41,0.23,-8.04
# 0.16,0.57,-7.74
# -0.03,0.19,-8.41
# 0.53,0.25,-8.16
# 0.28,0.40,-8.17
# 0.05,0.24,-8.01
# 0.14,-0.03,-8.28
# 0.36,0.24,-7.72
# 0.34,0.50,-8.09
# 0.20,-0.12,-7.92
# -0.06,0.23,-8.09
# 0.55,0.67,-7.89
# -0.06,0.20,-7.81
# 0.10,0.68,-7.83
# 0.47,0.35,-7.97
# 0.49,0.13,-8.08
# 0.32,0.73,-7.97
# 0.28,0.22,-7.72
# -0.19,0.48,-8.08
# 0.04,0.24,-7.83
# 0.23,0.29,-8.13
# 0.14,0.28,-7.92
# 0.00,0.32,-8.37
# 0.19,0.26,-8.17
# 0.11,0.41,-8.26
# 0.26,0.38,-7.93
# 0.01,0.27,-7.76
# 0.46,0.51,-8.16
# 0.15,0.46,-8.00
# -0.02,0.51,-8.04
# 0.27,0.15,-7.98
# 0.43,0.32,-8.27
# 0.16,-0.06,-7.96
# 0.21,0.27,-7.62
# 0.27,-0.16,-8.06
# 0.24,0.21,-8.02
# 0.32,0.51,-8.53
# 0.04,0.57,-7.88
# 0.06,0.46,-8.12
# -0.05,0.44,-8.15
# 0.25,0.45,-8.12
# -0.13,-0.03,-7.85
# -0.01,0.23,-8.17
# -0.02,0.85,-7.65
# 0.34,-0.14,-8.41
# 0.29,0.75,-7.86
# 0.23,0.15,-8.01
# 0.05,0.27,-7.76
# 0.29,0.41,-8.10
# 0.10,-0.01,-8.05
# -0.06,0.17,-8.19
# 0.42,0.28,-8.31
# -0.10,0.64,-7.83
# 0.27,0.17,-7.96
# -0.37,0.42,-7.66
# 0.38,0.45,-8.08
# 0.28,-0.16,-8.06
# 0.40,0.15,-7.95
# 0.22,-0.14,-8.03
# -0.07,0.11,-8.01
# 0.11,-0.04,-8.02
# 0.37,0.18,-8.00
# 0.29,-0.02,-7.75
# 0.23,0.41,-8.06
# 0.46,-0.24,-8.05
# 0.14,0.41,-7.94
# 0.29,0.48,-8.24
# 0.16,0.39,-8.22
# 0.19,0.00,-7.79
# 0.25,0.38,-8.29
# -0.39,0.25,-8.44
# 0.19,0.46,-7.72
# 0.12,0.03,-8.09
# 0.45,0.24,-8.12
# -0.22,0.12,-8.00
# 0.11,0.13,-8.04
# -0.15,0.49,-7.86
# 0.24,0.39,-7.93
# 0.43,0.45,-7.88
# 0.06,0.50,-8.03
# 0.18,0.45,-7.92
# 0.47,0.20,-8.16
# 0.41,0.20,-7.92
# 0.22,0.22,-8.32
# 0.25,0.31,-7.88
# 0.17,0.19,-8.12
# -0.01,0.57,-8.01
# 0.17,0.66,-7.98
# 0.19,0.24,-8.13
# 0.31,0.28,-8.23
# 0.29,0.29,-7.85
# 0.17,0.73,-8.20
# 0.12,0.21,-8.00
# 0.11,0.02,-7.98
# 0.11,0.41,-7.73
# 0.22,0.30,-7.69
# 0.20,0.19,-8.02
# -0.17,0.48,-8.07
# 0.08,0.02,-7.79
# 0.43,0.39,-8.14
# 0.17,0.20,-8.02
# 0.22,0.33,-7.99
# 0.44,0.22,-7.97
# 0.18,0.51,-7.92
# 0.08,-0.16,-7.85
# 0.41,0.47,-8.15
# 0.03,0.07,-7.95
# 0.44,0.77,-7.91
# 0.11,0.23,-8.09
# 0.34,0.48,-7.88
# -0.08,-0.06,-7.98
# 0.32,-0.07,-8.21
# -0.14,0.66,-8.04
# 0.40,-0.09,-8.03
# -0.06,-0.23,-7.85
# 0.49,0.21,-7.79
# 0.51,0.45,-8.36
# 0.58,-0.02,-8.12
# 0.34,0.72,-8.23
# 0.28,0.25,-8.36
# 0.22,0.47,-7.97
# 0.46,0.13,-8.37
# -0.03,0.78,-7.96
# 0.25,0.66,-7.90
# 0.27,0.07,-7.79
# -0.06,0.36,-7.79
# 0.13,0.57,-8.14
# 0.12,0.96,-8.00
# 0.34,0.18,-8.08
# 0.35,0.14,-8.28
# -0.07,0.17,-8.16
# 0.17,0.06,-8.01
# 0.35,-0.22,-8.14
# 0.39,0.35,-7.81
# 0.40,-0.08,-8.00
# 0.08,0.17,-7.91
# 0.74,0.31,-7.85
# 0.06,-0.05,-7.92
# 0.46,0.33,-7.89
# 0.00,0.35,-7.99
# 0.45,0.28,-8.03
# 0.40,0.12,-8.10
# 0.45,0.44,-8.05
# 0.21,0.50,-8.20
# 0.77,0.26,-8.08
# 0.11,0.30,-8.13
# -0.06,0.27,-8.07
# -0.12,0.51,-7.66
# 0.42,0.32,-7.92
# -0.02,0.14,-8.31
# 0.02,0.93,-8.15
# 0.57,0.29,-7.79
# 0.16,0.06,-8.05
# 0.04,0.17,-8.02
# -0.11,0.38,-7.76
# 0.23,0.26,-8.24
# 0.59,0.30,-8.18
# -0.06,0.10,-7.91
# 0.53,0.51,-8.19
# 0.62,-0.01,-7.80
# 0.24,0.30,-8.04
# 0.49,0.47,-7.85
# 0.28,-0.05,-8.04
# 0.70,0.28,-8.04
# 0.07,0.23,-8.15
# 0.38,0.52,-7.99
# 0.40,0.50,-7.94
# 0.26,0.94,-8.22
# 0.32,0.13,-7.72
# 0.41,0.34,-8.17
# 0.31,0.15,-8.02
# 0.34,0.24,-7.87
# 0.72,0.13,-7.93
# 0.21,0.77,-7.93
# 0.48,0.60,-7.89
# 0.17,0.59,-8.02
# 0.74,0.13,-8.49
# 0.26,0.28,-8.00
# -0.24,0.46,-8.07
# 0.25,0.26,-7.76
# 0.47,0.43,-8.14
# 0.45,0.53,-8.12
# 0.39,-0.04,-7.90
# 0.55,0.34,-8.11
# 0.28,0.49,-8.09
# 0.58,0.37,-7.90
# -0.18,0.42,-8.26
# 0.52,0.67,-7.91
# 0.62,0.57,-8.04
# -0.29,0.06,-7.80
# 0.32,0.32,-8.37
# 0.42,0.44,-7.93
# 0.07,0.24,-7.81
# -0.04,0.08,-8.03
# 0.35,0.68,-7.96
# 0.24,0.58,-8.09
# 0.27,0.50,-8.10
# 0.53,0.65,-7.75
# 0.16,-0.06,-8.25
# 0.16,0.56,-8.02
# 0.23,0.52,-8.09
# 0.45,0.26,-8.20
# 0.51,0.56,-8.33
# 0.59,0.36,-7.98
# 0.16,0.35,-7.99
# -0.16,0.65,-8.09
# -0.13,0.04,-7.90
# -0.04,-0.02,-7.80
# 0.20,0.29,-8.29
# 0.24,0.43,-8.12
# 0.26,0.25,-7.85
# -0.36,0.62,-8.03
# -0.19,0.08,-7.97
# -0.06,0.65,-8.01
# 0.30,0.12,-8.12
# 0.62,0.11,-7.97
# -0.14,0.35,-7.97
# 0.29,-0.11,-7.61
# 0.37,0.49,-8.03
# 0.39,0.06,-8.01
# 0.27,0.07,-8.34
# 0.34,-0.08,-8.08
# 0.07,0.12,-8.06
# 0.09,0.40,-8.22
# 0.34,0.82,-7.95
# 0.60,0.34,-8.16
# 0.03,0.26,-7.92
# 0.01,0.00,-7.92
# -0.01,0.18,-7.90
# 0.03,0.74,-7.97
# 0.51,0.55,-8.13
# 0.42,0.42,-8.01
# 0.23,0.37,-8.09
# 0.12,0.02,-8.17
# 0.34,0.50,-8.06
# 0.53,0.39,-8.27
# 0.44,0.56,-8.25
# 0.37,0.60,-7.83
# 0.12,0.44,-7.95
# 0.07,0.02,-7.93
# 0.08,0.41,-8.13
# 0.19,0.51,-8.20
# 0.51,0.45,-8.14
# 0.22,0.50,-7.81
# -0.27,0.54,-7.97
# 0.28,0.32,-8.20
# 0.33,0.18,-8.00
# 0.09,0.20,-8.17
# [[0.04, 0.18, -7.97], [0.28, 0.31, -7.86], [0.05, 0.2, -8.05], [0.09, 0.38, -8.06], [0.25, 0.07, -8.33], [0.46, 0.12, -8.08], [0.51, -0.17, -8.12], [0.37, 0.26, -8.16], [0.13, 0.66, -8.0], [0.51, 0.24, -7.87], [0.11, 0.42, -8.03], [-0.14, 0.48, -8.19], [0.13, 0.15, -7.86], [-0.15, 0.01, -7.82], [0.0, 0.0, -8.08], [0.18, 0.63, -8.04], [0.23, -0.1, -7.98], [0.4, 0.18, -8.15], [-0.14, 0.48, -8.04], [-0.04, -0.08, -8.12], [0.49, 0.51, -8.03], [0.53, 0.24, -7.85], [0.17, 0.03, -8.23], [-0.09, 0.08, -8.14], [0.11, 0.28, -7.97], [0.41, 0.57, -8.2], [0.26, 0.31, -8.28], [0.35, 0.16, -8.03], [0.65, 0.81, -7.93], [0.16, 0.06, -8.09], [-0.07, 0.77, -8.11], [0.25, 0.89, -7.72], [0.47, 0.5, -7.79], [-0.02, 0.57, -7.75], [0.26, 0.49, -8.16], [0.43, 0.4, -7.83], [0.17, 0.32, -8.09], [0.33, 0.0, -7.9], [0.1, 0.05, -7.81], [-0.0, 0.83, -8.09], [0.41, 0.57, -8.26], [0.63, 0.33, -7.92], [0.11, 0.22, -7.9], [0.13, 0.17, -8.21], [0.36, 0.18, -7.95], [0.35, 0.16, -8.15], [0.39, 0.47, -7.76], [0.17, 0.11, -7.92], [0.48, 0.22, -7.88], [-0.14, 0.51, -7.72], [0.01, 0.25, -8.03], [0.03, 0.85, -7.93], [0.41, 0.23, -8.04], [0.16, 0.57, -7.74], [-0.03, 0.19, -8.41], [0.53, 0.25, -8.16], [0.28, 0.4, -8.17], [0.05, 0.24, -8.01], [0.14, -0.03, -8.28], [0.36, 0.24, -7.72], [0.34, 0.5, -8.09], [0.2, -0.12, -7.92], [-0.06, 0.23, -8.09], [0.55, 0.67, -7.89], [-0.06, 0.2, -7.81], [0.1, 0.68, -7.83], [0.47, 0.35, -7.97], [0.49, 0.13, -8.08], [0.32, 0.73, -7.97], [0.28, 0.22, -7.72], [-0.19, 0.48, -8.08], [0.04, 0.24, -7.83], [0.23, 0.29, -8.13], [0.14, 0.28, -7.92], [0.0, 0.32, -8.37], [0.19, 0.26, -8.17], [0.11, 0.41, -8.26], [0.26, 0.38, -7.93], [0.01, 0.27, -7.76], [0.46, 0.51, -8.16], [0.15, 0.46, -8.0], [-0.02, 0.51, -8.04], [0.27, 0.15, -7.98], [0.43, 0.32, -8.27], [0.16, -0.06, -7.96], [0.21, 0.27, -7.62], [0.27, -0.16, -8.06], [0.24, 0.21, -8.02], [0.32, 0.51, -8.53], [0.04, 0.57, -7.88], [0.06, 0.46, -8.12], [-0.05, 0.44, -8.15], [0.25, 0.45, -8.12], [-0.13, -0.03, -7.85], [-0.01, 0.23, -8.17], [-0.02, 0.85, -7.65], [0.34, -0.14, -8.41], [0.29, 0.75, -7.86], [0.23, 0.15, -8.01], [0.05, 0.27, -7.76], [0.29, 0.41, -8.1], [0.1, -0.01, -8.05], [-0.06, 0.17, -8.19], [0.42, 0.28, -8.31], [-0.1, 0.64, -7.83], [0.27, 0.17, -7.96], [-0.37, 0.42, -7.66], [0.38, 0.45, -8.08], [0.28, -0.16, -8.06], [0.4, 0.15, -7.95], [0.22, -0.14, -8.03], [-0.07, 0.11, -8.01], [0.11, -0.04, -8.02], [0.37, 0.18, -8.0], [0.29, -0.02, -7.75], [0.23, 0.41, -8.06], [0.46, -0.24, -8.05], [0.14, 0.41, -7.94], [0.29, 0.48, -8.24], [0.16, 0.39, -8.22], [0.19, 0.0, -7.79], [0.25, 0.38, -8.29], [-0.39, 0.25, -8.44], [0.19, 0.46, -7.72], [0.12, 0.03, -8.09], [0.45, 0.24, -8.12], [-0.22, 0.12, -8.0], [0.11, 0.13, -8.04], [-0.15, 0.49, -7.86], [0.24, 0.39, -7.93], [0.43, 0.45, -7.88], [0.06, 0.5, -8.03], [0.18, 0.45, -7.92], [0.47, 0.2, -8.16], [0.41, 0.2, -7.92], [0.22, 0.22, -8.32], [0.25, 0.31, -7.88], [0.17, 0.19, -8.12], [-0.01, 0.57, -8.01], [0.17, 0.66, -7.98], [0.19, 0.24, -8.13], [0.31, 0.28, -8.23], [0.29, 0.29, -7.85], [0.17, 0.73, -8.2], [0.12, 0.21, -8.0], [0.11, 0.02, -7.98], [0.11, 0.41, -7.73], [0.22, 0.3, -7.69], [0.2, 0.19, -8.02], [-0.17, 0.48, -8.07], [0.08, 0.02, -7.79], [0.43, 0.39, -8.14], [0.17, 0.2, -8.02], [0.22, 0.33, -7.99], [0.44, 0.22, -7.97], [0.18, 0.51, -7.92], [0.08, -0.16, -7.85], [0.41, 0.47, -8.15], [0.03, 0.07, -7.95], [0.44, 0.77, -7.91], [0.11, 0.23, -8.09], [0.34, 0.48, -7.88], [-0.08, -0.06, -7.98], [0.32, -0.07, -8.21], [-0.14, 0.66, -8.04], [0.4, -0.09, -8.03], [-0.06, -0.23, -7.85], [0.49, 0.21, -7.79], [0.51, 0.45, -8.36], [0.58, -0.02, -8.12], [0.34, 0.72, -8.23], [0.28, 0.25, -8.36], [0.22, 0.47, -7.97], [0.46, 0.13, -8.37], [-0.03, 0.78, -7.96], [0.25, 0.66, -7.9], [0.27, 0.07, -7.79], [-0.06, 0.36, -7.79], [0.13, 0.57, -8.14], [0.12, 0.96, -8.0], [0.34, 0.18, -8.08], [0.35, 0.14, -8.28], [-0.07, 0.17, -8.16], [0.17, 0.06, -8.01], [0.35, -0.22, -8.14], [0.39, 0.35, -7.81], [0.4, -0.08, -8.0], [0.08, 0.17, -7.91], [0.74, 0.31, -7.85], [0.06, -0.05, - ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 26
#      24 # guardar en CSV
#      25 df = pd.DataFrame(train_data, columns=['x', 'y', 'z'])
# ---> 26 df['label'] = train_labels
#      27 df.to_csv("train_data_static.csv", index=False)
#
# File ~/Proyectos/physics-lab-experiments/.env/lib/python3.12/site-packages/pandas/core/frame.py:4322, in DataFrame.__setitem__(self, key, value)
#    4319     self._setitem_array([key], value)
#    4320 else:
#    4321     # set column
# -> 4322     self._set_item(key, value)
#
# File ~/Proyectos/physics-lab-experiments/.env/lib/python3.12/site-packages/pandas/core/frame.py:4535, in DataFrame._set_item(self, key, value)
#    4525 def _set_item(self, key, value) -> None:
#    4526     """
#    4527     Add series to DataFrame in specified column.
#    4528
#    (...)   4533     ensure homogeneity.
#    4534     """
# -> 4535     value, refs = self._sanitize_column(value)
#    4537     if (
#    4538         key in self.columns
#    4539         and value.ndim == 1
#    4540         and not isinstance(value.dtype, ExtensionDtype)
#    4541     ):
#    4542         # broadcast across multiple columns if necessary
#    4543         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/Proyectos/physics-lab-experiments/.env/lib/python3.12/site-packages/pandas/core/frame.py:5288, in DataFrame._sanitize_column(self, value)
#    5285     return _reindex_for_setitem(value, self.index)
#    5287 if is_list_like(value):
# -> 5288     com.require_length_match(value, self.index)
#    5289 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5290 if (
#    5291     isinstance(value, Index)
#    5292     and value.dtype == "object"
#    (...)   5295     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5296     # this deprecation
#
# File ~/Proyectos/physics-lab-experiments/.env/lib/python3.12/site-packages/pandas/core/common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (900) does not match length of index (300)

# %%
len(labels)
# Out:
# 900
